# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanankur108/eda-theory-da/blob/main/module_4_21bds0097.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Ankur Suman 21BDS0097

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
# 'Colab Notebooks'			        index-file.ipynb
#  data_mining_lab_assessment		        index-file.pdf
#  deep_learning_lab_assessment		        insta_sentiment_analysis_results.csv
#  emoji_usage.csv			        machine_learning_lab_assessment
#  endangered_animals_partitioned		        other-projects
#  exploratory-data-analysis		        project_final_year
#  face-recognition			        top_chat_partners.csv
#  foundation-of-data-science-theory-assessment

# %%
# %cd exploratory-data-analysis/
# Out:
# /content/drive/MyDrive/exploratory-data-analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
liver_data = pd.read_csv('/content/drive/MyDrive/exploratory-data-analysis/liver_data.csv')
liver_data[['Age of the patient', 'Total Protiens']] = liver_data.iloc[:, [3, 4]].values

# %%
print(liver_data.head())
# Out:
#    Age of the patient Gender of the patient  Total Bilirubin  \
# 0                 0.1                Female              0.7
# 1                 5.5                  Male             10.9
# 2                 4.1                  Male              7.3
# 3                 0.4                  Male              1.0
# 4                 2.0                  Male              3.9
#
#    Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 0               0.1                          187.0
# 1               5.5                          699.0
# 2               4.1                          490.0
# 3               0.4                          182.0
# 4               2.0                          195.0
#
#     Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 0                            16.0                             18.0
# 1                            64.0                            100.0
# 2                            60.0                             68.0
# ...

# %%
print(liver_data.tail())
# Out:
#        Age of the patient Gender of the patient  Total Bilirubin  \
# 30686                 1.0                  Male              2.2
# 30687                 1.3                  Male              2.9
# 30688                 3.0                  Male              6.8
# 30689                 1.0                Female              1.9
# 30690                 1.6                  Male              3.1
#
#        Direct Bilirubin   Alkphos Alkaline Phosphotase  \
# 30686               1.0                          610.0
# 30687               1.3                          482.0
# 30688               3.0                          542.0
# 30689               1.0                          231.0
# 30690               1.6                          253.0
#
#         Sgpt Alamine Aminotransferase  Sgot Aspartate Aminotransferase  \
# 30686                            17.0                             28.0
# 30687                            22.0                             34.0
# ...

# %%
print(liver_data.columns)
# Out:
# Index(['Age of the patient', 'Gender of the patient', 'Total Bilirubin',
#        'Direct Bilirubin', ' Alkphos Alkaline Phosphotase',
#        ' Sgpt Alamine Aminotransferase', 'Sgot Aspartate Aminotransferase',
#        'Total Protiens', ' ALB Albumin',
#        'A/G Ratio Albumin and Globulin Ratio', 'Result'],
#       dtype='object')

# %%
# Example: Distribution of Result column
sns.countplot(x='Result', data=liver_data)
plt.title('Distribution of Result')
plt.show()

# %%
# Print summary statistics
print(f"Summary Statistics for '{num_col}':")
print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Mode: {mode_val:.2f}")
print(f"Skewness: {skewness_val:.2f}")
print(f"Kurtosis: {kurtosis_val:.2f}")
# Out:
# Summary Statistics for 'Total Protiens':
# Mean: 289.08
# Median: 209.00
# Mode: 215.00
# Skewness: 3.78
# Kurtosis: 17.99

# %%
# Histogram
plt.figure(figsize=(8, 5))
plt.hist(liver_data[num_col], color='orange', edgecolor='black')
plt.title(f"Histogram of {num_col}")
plt.xlabel(num_col)
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Skewness Plot (Histogram + KDE)
plt.figure(figsize=(8, 5))
sns.histplot(liver_data[num_col], kde=True, color='green', edgecolor='black')
plt.title(f"Skewness Plot of {num_col}")
plt.xlabel(num_col)
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
# Select numerical column
num_col = 'Total Protiens'

# Calculate kurtosis
kurtosis_val = liver_data[num_col].kurt()
print(f"Kurtosis of '{num_col}': {kurtosis_val:.2f}")

# Plot KDE plot to visualize
plt.figure(figsize=(10, 6))
sns.kdeplot(liver_data[num_col], fill=True, color='orange')
plt.title(f"Kurtosis Plot of {num_col}")
plt.xlabel(num_col)
plt.ylabel("Density")
plt.grid(True)
plt.show()
# Out:
# Kurtosis of 'Total Protiens': 17.99

# %%
# Create a histogram with frequency
plt.figure(figsize=(10, 6))
liver_data[num_col].plot.hist(bins=20, edgecolor="black", color='orange')
plt.title(f"Frequency Distribution of {num_col}")
plt.xlabel(num_col)
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Box Plot
plt.figure(figsize=(8, 5))
sns.boxplot(x=liver_data[num_col], color='skyblue')
plt.title(f"Box Plot of {num_col}")
plt.xlabel(num_col)
plt.grid(True)
plt.show()

# %%
# Bar Plot
num_col = 'Total Protiens'

plt.figure(figsize=(12, 6))
liver_data[num_col].value_counts().sort_index().plot(kind="bar", color='skyblue')
plt.title(f"Bar Plot of {num_col}")
plt.xlabel(num_col)
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
# Create a cumulative frequencliver_data[['Result']] plot
plt.figure(figsize=(10, 6))
liver_data[num_col].plot(kind="hist", cumulative=True, bins=20, edgecolor="black", color='green')
plt.title(f"Cumulative Frequency Distribution of {num_col}")
plt.xlabel(num_col)
plt.ylabel("Cumulative Frequency")
plt.grid(True)
plt.show()

# %%
pip install python-ternary

# %%
import ternary
import matplotlib.pyplot as plt

# Data: Protein (%), Carbohydrates (%), Fats (%), Symbol
data = [
    (20, 55, 25, "o"),  # Patient 1
    (15, 60, 25, "s"),  # Patient 2 (Square)
    (30, 40, 30, "o"),  # Patient 3 (Circle)
    (10, 70, 20, "d"),  # Patient 4 (Diamond)
    (25, 45, 30, "^")   # Patient 5 (Triangle)
]

# Normalize Data: Convert percentages to proportions summing to 1
normalized_data = [(p/100, c/100, f/100, symbol) for p, c, f, symbol in data]

# Create a ternary plot
scale = 1  # Because data is already in proportions
figure, tax = ternary.figure(scale=scale)
tax.boundary(linewidth=2.0)  # Draw boundary
tax.gridlines(color="gray", multiple=0.1)  # Gridlines

# Plot points with respective symbols
for p, c, f, symbol in normalized_data:
    tax.scatter([(p, c, f)], marker=symbol, color='red', s=100, label=f"({p*100:.0f},{c*100:.0f},{f*100:.0f})")

# Set Labels
tax.left_corner_label("Protein (%)", fontsize=12)
tax.right_corner_label("Carbohydrates (%)", fontsize=12)
tax.top_corner_label("Fats (%)", fontsize=12)

# Ticks and styling
tax.ticks(axis='lbr', multiple=0.1, linewidth=1, fontsize=10)
tax.legend()
tax.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)

# %%
import pandas as pd
import ternary
import matplotlib.pyplot as plt

# Load liver dataset
liver_data = pd.read_csv('liver_data.csv')

# Remove extra spaces in column names
liver_data.columns = liver_data.columns.str.strip()

# Select three numeric columns
selected_cols = ['Total Bilirubin', 'Direct Bilirubin', 'Total Protiens']

# Drop NaN values
data = liver_data[selected_cols].dropna()

# Normalize data row-wise so that sum = 1 for each patient
normalized_data = data.div(data.sum(axis=1), axis=0)

# Convert to list of tuples
points = [tuple(x) for x in normalized_data.values]

# Create ternary plot
figure, tax = ternary.figure(scale=1)
tax.boundary(linewidth=2.0)
tax.gridlines(color="gray", multiple=0.1)

# Plot points
tax.scatter(points, marker='o', color='green', s=30, label='Patients')

# Set Labels
tax.left_corner_label("Total Bilirubin", fontsize=12)
tax.right_corner_label("Direct Bilirubin", fontsize=12)
tax.top_corner_label("Total Protiens", fontsize=12)

# Styling
tax.ticks(axis='lbr', multiple=0.1, linewidth=1, fontsize=10)
tax.legend()
tax.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
